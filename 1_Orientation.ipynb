# %% [markdown]
# <a href="https://colab.research.google.com/github/abbosaliboev/Data_Science/blob/main/1_Orientation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 실습 OT
#
# 목표: 다양한 머신러닝 및 딥러닝 활용
#
# 실습 계획 (tentative schedule)
# - 2주차: Pandas
# - 3주차: Apriori
# - 4주차: Linear Regression
# - 5주차: Multi Layer Perceptron
# - 6주차: Convolutional Nueral Networks and Recurrent Neural Networks
# - 7주차: Exploratory Data Analysis
# - 8주차: Transformer
# - 10주차: Clustering Algorithms
# - 11주차: Recommender Systems
# - 12주차: Graph Convolutional Networks
# - 13주차: LoRA (Low-Rank Adaptation) with Transformers
# - 14주차: Self Supervised Learning (Contrastive Learning)

# %% [markdown]
# # Colaboratory 란?
# Colaboratory, 줄여서 colab을 사용하면 브라우져에서 python을 작성하고 실행할 수 있습니다. Colab은 다음과 같은 특징을 가집니다.
# - python은 google cloud 기반의 서버에서 실행되므로 사용자 PC의 부담이 없음
# - Google에서 제공하는 GPU 및 TPU의 무료 엑세스

# %% [markdown]
# # Hello world, hello colab

# %% [markdown]
# 지금 보고계신 페이지는 정적 웹페이지가 아닌, interpreter 환경인 jupyter notebook 기반의 colab입니다.
#
# Colab에서는 입력 가능한 하나의 칸을 cell이라고 부릅니다. 현재 cell은 markdown 기반의 text cell이며, 다음은 간단한 Python script가 포함된 code cell입니다.

# %%
print('Hello world, hello colab')
testnumber = 120 * 60000
print(testnumber)
# Out:
# Hello world, hello colab
# 7200000

# %% [markdown]
# 위 cell의 코드를 실행하려면 cell을 클릭하여 코드 왼쪽의 실행 버튼을 누르거나, 단축키 **'Ctrl+Enter / Shift+Enter'**를 사용하세요. Cell을 클릭하면 코드를 수정할 수 있습니다.
#
# 특정 셀에서 정의한 변수는 나중에 다른 셀에서 사용이 가능합니다.

# %%
print(testnumber * 234)
# Out:
# 1684800000

# %% [markdown]
# Colab을 수정하고 저장하면 해당 파일은 google drive계정의 폴더에 저장됩니다.

# %% [markdown]
# # Colab 사양 및 GPU 사용

# %% [markdown]
# Colab은 Linux 기반입니다. Linux 명령어 앞에 !를 붙이면 해당 명령어를 실행할 수 있습니다.

# %% [markdown]
# - 운영체제

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 22.04.4 LTS

# %% [markdown]
# - CPU 사양

# %%
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0xffffffff
# cpu MHz		: 2000.152
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi its
# bogomips	: 4000.30
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 85
# model name	: Intel(R) Xeon(R) CPU @ 2.00GHz
# stepping	: 3
# microcode	: 0xffffffff
# cpu MHz		: 2000.152
# cache size	: 39424 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm mpx avx512f avx512dq rdseed adx smap clflushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec xgetbv1 xsaves arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs taa mmio_stale_data retbleed bhi its
# bogomips	: 4000.30
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %% [markdown]
# - 메모리 사양

# %%
# !cat /proc/meminfo
# Out:
# MemTotal:       13286964 kB
# MemFree:         8613956 kB
# MemAvailable:   12084548 kB
# Buffers:          151212 kB
# Cached:          3427356 kB
# SwapCached:            0 kB
# Active:           522932 kB
# Inactive:        3682412 kB
# Active(anon):       1408 kB
# Inactive(anon):   627356 kB
# Active(file):     521524 kB
# Inactive(file):  3055056 kB
# Unevictable:           8 kB
# Mlocked:               8 kB
# SwapTotal:             0 kB
# SwapFree:              0 kB
# Dirty:               288 kB
# Writeback:             0 kB
# AnonPages:        626932 kB
# Mapped:           431732 kB
# Shmem:              1980 kB
# KReclaimable:     219656 kB
# Slab:             270648 kB
# SReclaimable:     219656 kB
# SUnreclaim:        50992 kB
# KernelStack:        6016 kB
# PageTables:         9788 kB
# SecPageTables:         0 kB
# NFS_Unstable:          0 kB
# Bounce:                0 kB
# WritebackTmp:          0 kB
# CommitLimit:     6643480 kB
# Committed_AS:    2759648 kB
# VmallocTotal:   34359738367 kB
# VmallocUsed:       58128 kB
# VmallocChunk:          0 kB
# Percpu:             1096 kB
# HardwareCorrupted:     0 kB
# AnonHugePages:         0 kB
# ShmemHugePages:        0 kB
# ShmemPmdMapped:        0 kB
# FileHugePages:         0 kB
# FilePmdMapped:         0 kB
# CmaTotal:              0 kB
# CmaFree:               0 kB
# Unaccepted:            0 kB
# HugePages_Total:       0
# HugePages_Free:        0
# HugePages_Rsvd:        0
# HugePages_Surp:        0
# Hugepagesize:       2048 kB
# Hugetlb:               0 kB
# DirectMap4k:      107312 kB
# DirectMap2M:     5132288 kB
# DirectMap1G:    10485760 kB

# %% [markdown]
# Colab은 GPU를 무료로 사용할 수 있습니다. 메뉴의 런타임>런타임 유형 변경>하드웨어 가속기를 GPU로 바꾸면 GPU를 활용 가능한 상태로 바뀝니다.

# %%
# !nvidia-smi
# Out:
# Mon Mar  9 01:08:19 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   52C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# Colab에서 제공하는 GPU는 nvidia tesla K80으로, 기본적인 딥러닝 모델을 학습시키는 데에 문제가 없는 성능을 가지고 있습니다. 다만, GPU를 활용하면 해당 colab notebook의 최대 실행시간이 12시간으로 제한됩니다. 이를 연장하려면 추가적인 결제가 필요합니다.

# %% [markdown]
# # Google drive 연동

# %% [markdown]
# colab에 데이터를 로드할 때 로컬 컴퓨터의 파일을 업로드 할 수도 있지만, colab의 런타임이 종료되면 업로드한 파일이 사라져 매번 새로 업로드 해야하는 불편함이 있습니다.
#
# 따라서 보통 colab에 Google drive를 마운트 하고, drive에서 파일을 가져오는 방식으로 주로 활용합니다.

# %% [markdown]
# ##  Google Drive 마운트하기
#
# 아래의 예시에서는 승인 코드를 사용해 런타임에 Google Drive를 마운트하는 방법 및 이 드라이브에서 파일을 쓰고 읽는 방법을 보여 줍니다. 이 예시를 실행하면 <a href="https://drive.google.com/">https://drive.google.com/</a>에 새 파일&#40;<code>foo.txt</code>&#41;이 표시됩니다.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 위 코드를 실행시키면 authorization code를 받을 수 있는 링크가 나옵니다. 해당 링크에서 code를 복사하여 입력하면 mount가 완료됩니다.
#
# 마운트가 완료되면, '/content/drive/My Drive' 의 경로로 본인의 google dirve에 접근할 수 있습니다.

# %%
with open('/content/drive/My Drive/foo.txt', 'w') as f:
  f.write('Hello Google Drive123!')
# !cat /content/drive/My\ Drive/foo.txt
# Out:
# Hello Google Drive123!
